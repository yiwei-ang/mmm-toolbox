# %%
# # To reload: 
import os
import glob
import cmdstanpy
cmdstanpy.install_cmdstan()

DIR = 'model_output'

csv_files = glob.glob(os.path.join(DIR, '*.csv'))

import cmdstanpy
saved_model = cmdstanpy.from_csv(csv_files)
saved_model.summary()
# Out:
# CmdStan install directory: C:\Users\User\.cmdstan
# Installing CmdStan version: 2.34.1
# ...
# Download successful, file: C:\Users\User\AppData\Local\Temp\tmpizf5hr3r
# Extracting distribution
# Unpacked download as cmdstan-2.34.1
# Building version cmdstan-2.34.1, may take several minutes, depending on your system.
# Installed cmdstan-2.34.1
# Test model compilation
#                                         Mean      MCSE      StdDev  \
# lp__                            -2473.450000  0.062978    4.991040
# beta_base_revenue                   0.827615  0.000212    0.030049
# beta_google_performance_max       943.482000  0.341988   56.365600
# param_A_google_performance_max      1.881420  0.000668    0.116620
# param_B_google_performance_max    867.547000  0.662924   94.823400
# ...                                      ...       ...         ...
# mu[361]                         10651.000000  0.602950   96.227800
# mu[362]                          9725.560000  0.489546   76.164300
# ...
